# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mahnoor-ImranK/FlyRank-AI-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
REPO_URL = "https://github.com/Mahnoor-ImranK/FlyRank-AI-Internship"

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I chose the **Refresh / Content Opportunity Scoring** lane because I think it is interesting and useful. Many websites have a lot of pages, so it is difficult to check every page manually. This project will help identify which pages should be reviewed first. I also selected this lane because it matches the starter notebooks that I already completed, so it will be easier for me to continue working on it in the coming weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Research Question**
#
# Can machine learning help identify which web pages should be refreshed first?
#
# **Unit of Analysis**
#
# The unit of analysis is a single web page.
#
# **Output**
#
# The output will be a ranked list of pages that should be reviewed for content refresh.
#
# **Decision**
#
# The decision is which pages should be updated first.
#
# **Action**
#
# The SEO or content team can review the recommended pages and update their content if needed.
#
# **Cost of a Wrong Recommendation**
#
# If a page is recommended even though it does not need an update, time and effort will be wasted. If a declining page is not recommended, it may continue losing traffic and rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains information about 30,000 web pages. It includes useful features like search volume, impressions, CTR, average position, and trend direction. These features can help understand which pages are performing well and which pages may need a content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("/content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Declining Pages:", (df["trend_direction"] == "down").sum())
print("Average CTR:", round(df["ctr"].mean(), 3))
# Out:
# Total Pages: 30000
# Declining Pages: 16262
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project can find patterns in the available data and help identify pages that may need a content refresh. The results can support decision-making, but they should be treated as recommendations.
#
# This project cannot prove that a certain factor directly improves rankings or predict how Google's algorithm works. The results only show patterns found in the dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
#
# Checklist:
# - I completed all the required sections.
# - The notebook runs without any errors.
# - I did not include any private client information.
# - My answers are based on observations from the data.
# - I will save this notebook in my GitHub repository before submitting it.
